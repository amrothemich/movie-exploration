# %%
import pandas as pd

# %%
df_rtmovies = pd.read_csv('rotten_tomatoes_movies.csv')

# %%
df_rtreviews = pd.read_csv('rotten_tomatoes_reviews.csv')

# %%
df_rtmovies.head()
# Out:
#                      rotten_tomatoes_link  \
# 0                              /m/0814255
# 1                              /m/0878835
# 2                                   /m/10
# 3                 /m/1000013-12_angry_men
# 4  /m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus  \
# ...

# %%
df_rtreviews.head()
# Out:
#   rotten_tomatoes_link review_date          critic_publication critic_icon  \
# 0           /m/0814255  2015-01-09             Cinemaphile.org      Rotten
# 1           /m/0814255  2012-07-31                 7M Pictures       Fresh
# 2           /m/0814255  2011-11-05  Star-Democrat (Easton, MD)      Rotten
# 3           /m/0814255  2011-04-25              ComingSoon.net      Rotten
# 4           /m/0814255  2011-04-04                  Movies.com      Rotten
#
#   critic_top  critic_score                                     review_content
# 0        NaN           NaN  The plot uses the presence of the Greek gods a...
# 1        NaN           NaN  It provides a great adventure movie for the fa...
# 2        NaN           NaN  The premise of Percy Jackson & the Olympians: ...
# 3        NaN           NaN  Percy Jackson is simply uninspired in every si...
# 4        NaN           NaN    It kind of just builds up to a lot of Not Much.

# %%
import numpy as np

# %%
rt_fdialogue = df_rtmovies[['movie_title','directors','tomatometer_status','tomatometer_rating','tomatometer_count','audience_rating','audience_count']].copy()

# %%
rt_fdialogue.head()
# Out:
#                                          movie_title          directors  \
# 0  Percy Jackson & the Olympians: The Lightning T...     Chris Columbus
# 1                                        Please Give  Nicole Holofcener
# 2                                                 10      Blake Edwards
# 3                    12 Angry Men (Twelve Angry Men)       Sidney Lumet
# 4                       20,000 Leagues Under The Sea  Richard Fleischer
#
#   tomatometer_status  tomatometer_rating  tomatometer_count  audience_rating  \
# 0             Rotten                  49                144             53.0
# 1    Certified Fresh                  86                140             64.0
# 2              Fresh                  68                 22             53.0
# 3    Certified Fresh                 100                 51             97.0
# 4              Fresh                  89                 27             74.0
#
#    audience_count
# 0        254287.0
# 1         11567.0
# ...
